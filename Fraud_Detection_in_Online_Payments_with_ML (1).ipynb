# %% [markdown]
# 1. Data Preparation
#
# Importing essential libraries for data analysis and modeling

# %%
#padas are imported for manipulation of data and handling structures datasets

import pandas as pd

#For numerical operations and arraybased computations NumPy got imported
import numpy as np

#Seaborn and Matplotlib is used for VISUALIZING THE DATA toc exploring patterns and results
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing dataset of online fraud dectection**

# %%
# Load the CSV file of payments fraud detection dataset
data = pd.read_csv('PS_20174392719_1491204439457_log.csv')

# %%
data
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %% [markdown]
# * **data.info()** is the method that
# provides a concise summary of a DataFrame which is in context towards the Python Pandas Library.
# *  The main purpose of the designed in giving us the quick overview of the structure and characteristics of your / our data. It's particulary helpful for probing the analysis of data, helping us in understanding the data what we are working with.
# * With this data frame we can quickly see that which columns have missing values.
# *  Also, we can verify the data types that are as expected. By understanding the number of rows and columns.
# *  Get an idean of how much memory the DataFrame is consuming, this data.info() is more valuable tool in getting the *first look * of our data, helping us in understanding the structure and identify potential issues.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %% [markdown]
# ***data.describe()*** method which is a powerful tool for quickly generating descriptive statistics that summarize the central tendency, dispersion, and shape of a dataset's distribution.
# *  In the statistical summary which calsulates and returns key statistical measures for numerical columns in a *Pandas DataFrame or Series*. Also provide the summary for statistics for categorical columns, through the measures differ.
# * It's invaluable for initial data exploration, providing a high-level overview of the data's characetistics.

# %%
data.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
#We are going to check the missing values in our dataset
data.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
#We are going to find the duplicates values if it is present in the dataset
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#iterating each column to count occurances of null values
for i in data.columns:
  print(i)
  print(data[i][data[i].isnull()==True].count())
# Out:
# step
# 0
# type
# 0
# amount
# 0
# nameOrig
# 0
# oldbalanceOrg
# 0
# newbalanceOrig
# 0
# nameDest
# 0
# oldbalanceDest
# 0
# newbalanceDest
# 0
# isFraud
# 0
# isFlaggedFraud
# 0

# %%
#Iterate through each column to count occurrences of zero values
for col in data.columns:
  print(f"Zero values in {col}: {(data[col] == 0).sum()}")
# Out:
# Zero values in step: 0
# Zero values in type: 0
# Zero values in amount: 16
# Zero values in nameOrig: 0
# Zero values in oldbalanceOrg: 2102449
# Zero values in newbalanceOrig: 3609566
# Zero values in nameDest: 0
# Zero values in oldbalanceDest: 2704388
# Zero values in newbalanceDest: 2439433
# Zero values in isFraud: 6354407
# Zero values in isFlaggedFraud: 6362604

# %%
# Removing the transactions with zero amounts as they represent redundant or invalid entries
data = data[data['amount'] != 0]
print(data)
#This is also another way to remove transactions with zero amounts as they are going to represent redudndant or enteries that are invalid
#data=data[data['amount'] > 0].copy()
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %% [markdown]
# *  By filtering out zero-amount transactions, we've made better quality for our data, making it fitting for deeper investigation.
# *  In our next steps, we are going to analyze the unique entries in ***'type', 'isFraud', 'isFlaggedFraud'*** as in going to recognize their numerous categories and distributions, which is going to help us in exploring **Fraud detection**.

# %% [markdown]
# Below are two ways in extracting the categorical columns for exploring the their distinct categories.
#
# In Type 1 with help of for loop extracted the unique values

# %%
# Type 1: Extract unique values for categorical columna to explore their distinct categories
categorical_columns = ['type', 'isFraud', 'isFlaggedFraud']

for column in categorical_columns:
    unique_values = data[column].unique()
    print(f"Unique values in column '{column}':")
    print(unique_values)
    print()
#display the unique values for each columns
print(data['type'].unique())
print(data['isFraud'].unique())
print(data['isFlaggedFraud'].unique())
# Out:
# Unique values in column 'type':
# ['PAYMENT' 'TRANSFER' 'CASH_OUT' 'DEBIT' 'CASH_IN']
#
# Unique values in column 'isFraud':
# [0 1]
#
# Unique values in column 'isFlaggedFraud':
# [0 1]
#
# ['PAYMENT' 'TRANSFER' 'CASH_OUT' 'DEBIT' 'CASH_IN']
# [0 1]
# [0 1]

# %%
# Extracting unique values for categorical columns to explore their distinct categories

unique_values_type = data['type'].unique()
unique_values_isFraud = data['isFraud'].unique()
unique_values_isFlaggedFraud = data['isFlaggedFraud'].unique()

# Display the unique values for each column
print("Unique values in 'type' column:", unique_values_type)
print("Unique values in 'isFraud' column:", unique_values_isFraud)
print("Unique values in 'isFlaggedFraud' column:", unique_values_isFlaggedFraud)
# Out:
# Unique values in 'type' column: ['PAYMENT' 'TRANSFER' 'CASH_OUT' 'DEBIT' 'CASH_IN']
# Unique values in 'isFraud' column: [0 1]
# Unique values in 'isFlaggedFraud' column: [0 1]

# %% [markdown]
# *  After a careful examination of our current dataset which is revealing the presence of three columns intended to represent categorical information. while we have made progress in transforming these non-numerical features into a format that is going to suit the *Machine Learning*, a critical inconsistency persists.
# *  Specifically, the *'isFraud'* and *'isFlaggedFraud'* columns have been effectively converted to numerical representations, likely through techniques like *binary encoding* or similar methods.
# *  However, the 'TYPE' column, which categorizes transaction types, remains in its original categorical form. This difference in representation poses a potential challenge. ML Algorithms generally perform optimally with numerical inputsm and the presence of a non-numerical column can impede model training and performance.
# *  Hence, an important step in our data preprocessing pipelines are going to be addresed with the discrepancy by applying appropriate encoding techniques to the 'TYPE' column. This transformation will ensure uniformity across all features, enabling us to build a more robust and accurate fraud detection model.

# %%
#we are going to label encoding the 'type' column since it is categorical and we need numbers for modeling
data['type']= data['type'].map({'CASH_OUT':0, 'PAYMENT':1, 'CASH_IN':2, 'TRANSFER':3, 'DEBIT':4})
#data['isFraud']= data['isFraud'].map({0:'No Fraud', 1:'Fraud'})
#data['isFlaggedFraud']= data['isFlaggedFraud'].map({0:'No Fraud', 1:'Fraud'})
# Out:
# <ipython-input-13-2e6511b42fc5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['type']= data['type'].map({'CASH_OUT':0, 'PAYMENT':1, 'CASH_IN':2, 'TRANSFER':3, 'DEBIT':4})

# %% [markdown]
# Here we are going to examine the distribution of transaction types and inspect the number of transactions in the datasets. If we observe that an imbalance in our dataset then, we are going to address this issue using, transformation tools such as *log, robust, Synthetic Minority Over-sampling Technique (SMOTE)* for making sure to be better model performance and more accurate prediction.

# %% [markdown]
# **2. Exploratory Data Analysis (EDA) ON RAW DATA**
#
# Now lets see how many fraud cases we have among all the transactions.

# %%
# We are getting the value that counts for the 'isFraud' variables
isFraud_counts = data['isFraud'].value_counts()

# Display the value counts
print("Value Counts:\n",isFraud_counts)
# Out:
# Value Counts:
#  isFraud
# 0    6354407
# 1       8197
# Name: count, dtype: int64

# %%
#For visualizing the data we are ploting the bar or countplot that
#is between the distribution of Fraudulent vs normal distribution.
sns.countplot(x='isFraud', data=data, order=isFraud_counts.index, palette='viridis')
plt.title('Distribution of Fraudulent vs Normal Transactions')
plt.xlabel('Transaction Type')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-15-0cf5157450ae>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='isFraud', data=data, order=isFraud_counts.index, palette='viridis')

# %% [markdown]
# The dataset is revealilng a substantial calss imbalance within the *'isFraud'* column, where the vast majority of transactions are non-fraudulant, a typical characterristic of fraud detection scenarios. While this imbalance presents a challenge by potentially skewing models toward predicting non-fraudulent outcomes and hindering the detection of rare fraudulent cases, we are going to postpone addressing it until after completing the *Exploratory Data Analysis (EDA)*. This dely is crucial to preserve the raw data's inherent patterns during our initial investigation. Following the EDA, we will employ techniques like *oversampling, undersampling, or classweight* adjustments to mitigate the imbalance. To accurately evaluate model performance in this context, we'll rely on metrics such as precision, recall, and the F1-score, as traditional accuracy metrics can be misleading when dealing with imbalanced dataset.

# %% [markdown]
# * With the goal of understanding the factors that contributes to fraudulent transactions, we will now shift our attention to the *'isFraud'* column, which serves as our critical target variables.
# *  This variable, indicating whether a transaction is fraudulent or not, will be the focal point of our analysis. Specifically, we aim in examining the relationships among this binary target and the remaining numerical columns withinb the dataset.
# * By exploring how these numerical features vary across fraudulant and non-fraudulant transactions, we can uncover potential patterns and correlations that may be inicative of fradulant activity. This investigation will involve comparing statistical distributions, calculating correlation coefficients, and potentially visualizing these realtionships to gian a deeper understanding of the underlying dynamics and inform the development of an effective fraud detection models.
# * To investigate the potential influence of transaction details on fraud, we've chosen to focus on several numerical variables: *'amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', and 'newbalanceDest'. * These columns, which capture the monetary value of transaction, are hypothesized to contain critical information that can differentiate between legitimate and fraudulent activitites.

# %%
#list of selected features to analyze
selected_features = ['type', 'amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest']
print(selected_features)

# Create subplots (number of subplots is equal to the number of selected features)
fig, axes = plt.subplots(nrows=len(selected_features), figsize=(10, 5 * len(selected_features)))
# Loop through each selected feature to create individual bar plots
for i, feature in enumerate(selected_features):
    sns.barplot(x=data['isFraud'], y=data[feature], data=data, ax=axes[i])
    axes[i].set_title(f'Distribution of {feature} by isFraud')
    axes[i].set_xlabel('isFraud')
    axes[i].set_ylabel(feature)
# Add a title for the overall figure and adjust layout for better spacing
plt.suptitle("Comparison of Selected Features with Target", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# ['type', 'amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest']

# %% [markdown]
# **Key Observations fom the Feature Analysis**
# 1.   **Transaction Amount (amount):** The analysis reveals a clear patterns by fraudualent trasnactions are characterized by susdtantially higher monetry values than their non-fraudulant counterparts. This obervation implies that indiviaduals engaging in fraudulent activities tend to prioritize high-value transactions, likely as a strategy to amplify their potential financial gains.
# 2. **Origin Account Balance (oldbalanceOrg):** The data indicating that fraudulent trasnactions are disproportionately associated with accounts holding larger initial balances. This patterns suggests a strategy where perpetrators target accounts with substantial funds, enabling them to execute transfers of greater monetory value, which supports by the obseved higher average balance of origin accoiunts in
# 1. **Origin Account Balance (oldbalanceOrg):** A notable characteristic of fraudulant transactions is the drastic reduction, or complete elimination, of the origin account's balance following the transfer. This behavior, where fraudsters effectively empty or near-empty the originating accounts, serves as a significant red flag, suggesting a deliberate attempt to conceal or rapidly extract the stolen funds.
# 2. **Destination Account Balance Before Transaction (oldbalanceDest):** Fraudsters often use destination accounts with low balances to recieve money. This could imply that they prefer using new or less-monitored acccounts to avoid detection.

# %% [markdown]
# **Let’s check which transaction type is the most common in our dataset**

# %%
#grab the value counts for the 'type' column to see the breakdown
type_counts = data['type'].value_counts()
print("Value Counts:\n",type_counts)
# Out:
# Value Counts:
#  type
# 0    2237484
# 1    2151495
# 2    1399284
# 3     532909
# 4      41432
# Name: count, dtype: int64

# %%
#plot a count type to visualize transaction type popularity
plt.figure(figsize=(8, 6))
sns.countplot(x='type', data=data, order=type_counts.index, palette='viridis')
plt.title('Transaction Type Popularity')
plt.xlabel('Transaction Type')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-18-f0499c406833>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='type', data=data, order=type_counts.index, palette='viridis')

# %% [markdown]
# Note that for 0: CASH_OUT; 1: PAYMENT; 2: CASH_IN; 3:TRANSFER; 4: DEBIT
#
# This must be highlight which type's most frequent-pretty handy for spotting tends!

# %% [markdown]
# Looking at the distribution of 'type' after label encoding:
# * It is pretty imbalanced- CASH_OUT and PAYMENT dominate, while DEBIT's way smaller.
# * Since we are working on fraud detection and haven't changed 'type' yet, this imbalance might not hurt too much.
# *  If our bettrt model example something tree-based like Random Forest can handle it.
# *  Still, if 'type' ties closely to 'isFraud' and we see skew in predictions later,
# we could balance it with oversampling (SMOTE) or undersampling—just not right now during EDA.

# %% [markdown]
# **so as we saw on graph only two transation type is most used so now we will examine that is that in which type of transaction fraud occured the most.**

# %%
#create a  contingency table (cross-tabulation) between isFraud and type
contingency_table = pd.crosstab(data['isFraud'], data['type'])
print(contingency_table)
# Out:
# type           0        1        2       3      4
# isFraud
# 0        2233384  2151495  1399284  528812  41432
# 1           4100        0        0    4097      0

# %%
# Plot heatmap for the contingency table
plt.figure(figsize=(8, 6))
sns.heatmap(contingency_table, annot=True, fmt='d', cmap='Greys', cbar=False)
plt.title('Contingency Table Heatmap')
plt.xlabel('Transaction Type')
plt.ylabel('isFraud')
plt.show()

# %% [markdown]
# **PART 3: Feature Engineering**
#
# **Focusing on Fraud-Prone Transaction Types.**
#
# Our analysis reveals a striking pattern: All instances of fraud within the dataset are confines to just two transaction categories, **'cashout' and 'transfer'**, with roughly equal occurances. Notably, the remaining transaction types- ***'payment', 'debit', and 'cash_in'*** - show no evidance of fraudulant activity. This Concentrated occurences suggets that fraudsters specifically target ***'cashout' and 'transfer'*** transactions, likely due to the enhanced ability these methods provide to rapidly move illicit funds either out of the system or between accounts, thus facilitating their criminal objectives.

# %%
#We are going to define the weights with our transaction types by using numeric values
transaction_type_weights = {
    0: 2.0,  # CASH_OUT
    1: 1.0,  # PAYMENT
    2: 1.0,  # CASH_IN
    3: 2.0, # TRANSFER
    4: 1.0  # DEBIT
}
#For missing categories we are assigining the weights with default values.
data['transaction_type_weight'] = data['type'].map(lambda x: transaction_type_weights.get(x, 1.0))
print(data['transaction_type_weight'])
# Out:
# 0          1.0
# 1          1.0
# 2          2.0
# 3          2.0
# 4          1.0
#           ...
# 6362615    2.0
# 6362616    2.0
# 6362617    2.0
# 6362618    2.0
# 6362619    2.0
# Name: transaction_type_weight, Length: 6362604, dtype: float64
# <ipython-input-21-b0da4583f4e2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['transaction_type_weight'] = data['type'].map(lambda x: transaction_type_weights.get(x, 1.0))

# %% [markdown]
# The ***exploratory data analysis (EDA) *** process is being hampered by the data's significant skewness and the presence of numerous outliers, making effective visualization challenging. To address these issues and facilitate clearer data analysis, a normalization strategy will be implemented.
#
# Specifically, the 'amount' columns, which is particularly susceptible to outliers, will be transformed using *RobustScaler,* a techniwue designed to mitigate the impact of extreme values. For the remaining numerical columns, a logarithmic transformation will be applied. This approach will reduce skewness, resulting in a more symmetrical data distribution and consequently, improving the clarity and interpretability of visualizations during EDA phase.

# %%
from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler


# Initializing the  scalers
robust_scaler = RobustScaler()

# Transformations are applied here
data['amount_scaled'] = robust_scaler.fit_transform(data[['amount']])

# Log transformations are applied in preventing the dominance of zero]
data['oldbalanceOrg_log'] = np.log1p(data['oldbalanceOrg'])
data['newbalanceOrig_log'] = np.log1p(data['newbalanceOrig'])
data['oldbalanceDest_log'] = np.log1p(data['oldbalanceDest'])
data['newbalanceDest_log'] = np.log1p(data['newbalanceDest'])

#Printing the data that is scaled
print(data[['amount_scaled', 'oldbalanceOrg_log', 'newbalanceOrig_log',
                        'oldbalanceDest_log', 'newbalanceDest_log']].describe())
# Out:
# <ipython-input-22-b3e95f2d294e>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['amount_scaled'] = robust_scaler.fit_transform(data[['amount']])
# <ipython-input-22-b3e95f2d294e>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['oldbalanceOrg_log'] = np.log1p(data['oldbalanceOrg'])
# <ipython-input-22-b3e95f2d294e>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ***Analyzing Fraud Rates by Transaction Amount Bins***
#
#
# For understaning the fraud varies across different transaction amounts, I binned the amount columns into predefined ranges and calculated the fraud rate for each bins. This is going to help in recognizing which transactions amounts that are most susceptible fraud.

# %%
#defining amount bins and labels
amount_bins = [0, 100, 500, 1000, 5000, 10000, 50000, 100000, 1000000, float('inf')]
#define labels
amount_labels = ['0-100', '100-500', '500-1K', '1K-5K', '5K-10K', '10K-50K', '50K-100K', '100K+', '1000K+']
#Bin the transaction amounts
data['amount_binned'] = pd.cut(data['amount'], bins=amount_bins, labels=amount_labels)
# Out:
# <ipython-input-23-bb3810a0eccf>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['amount_binned'] = pd.cut(data['amount'], bins=amount_bins, labels=amount_labels)

# %%
#calculated fraud rate per bin in a seperate dataframe also add the renaming of the columns of count and sum
fraud_rate_per_bin = data.groupby('amount_binned')['isFraud'].agg(['count', 'sum']).rename(columns={'count': 'Total_Transaction_Count', 'sum': 'Fraud_Transaction_Count'})
#do average for the Fraud_Transaction_Count and Total_Transaction_Count
fraud_rate_per_bin['Fraud_Rate'] = fraud_rate_per_bin['Fraud_Transaction_Count'] / fraud_rate_per_bin['Total_Transaction_Count']


#reset the index for readability
fraud_rate_per_bin = fraud_rate_per_bin.reset_index()

print(fraud_rate_per_bin)
# Out:
#   amount_binned  Total_Transaction_Count  Fraud_Transaction_Count  Fraud_Rate
# 0         0-100                    14089                        2    0.000142
# 1       100-500                    56987                       34    0.000597
# 2        500-1K                    71554                        6    0.000084
# 3         1K-5K                   559855                      104    0.000186
# 4        5K-10K                   583590                      116    0.000199
# 5       10K-50K                  1519856                      760    0.000500
# 6      50K-100K                   719351                      669    0.000930
# 7         100K+                  2706696                     3800    0.001404
# 8        1000K+                   130626                     2706    0.020716
# ...

# %% [markdown]
# ***Assigning Weights to Transaction Amount Bins***
#
# To enhance the model's ability to detect fraud within critical transaction value ranges, a weighting system was implemented based on 'amount_bin' categories. Bins representing higher transaction amoounts, specifically those those exceeding 100,000 and 1,000,000, were assigned significantly greater weights. This strategic weighting ensures that the model places a higher emphasis on learning patterns associated with these high-value transactions, thereby improving its performance in identifying high-risk fraudulent activities.

# %%
#define weights for each transaction amount bin
amount_bin_weights = {
    '0-100': 1.0,
    '100-500': 1.0,
    '500-1K': 1.0,
    '1K-5K': 1.0,
    '5K-10K': 1.0,
    '10K-50K': 1.0,
    '50K-100K': 1.0,
    '100K+': 1.5,
    '1000K+': 2.0
}

# %% [markdown]
# With the dataset now thoroughly prepared through cleaning, filtering, and transformations, we will proceed to employ visual analysis techniques to uncover underlying patterns and pinpoint the areas where fraudulent activity is most concentrated. This visual exploration aims to elucidate the specific features or conditions that exhibit a strong correlation with fraudulent transactions, providing valuable insights into the characteristics that distinguish them from legitimate transactions.

# %%
#assign bin weights to the data dataframes
data['amount_bin_weight'] = data['amount_binned'].map(lambda x: amount_bin_weights.get(x, 1.0))
print(data['amount_bin_weight'])
# Out:
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
#           ...
# 6362615    1.5
# 6362616    2.0
# 6362617    2.0
# 6362618    1.5
# 6362619    1.5
# Name: amount_bin_weight, Length: 6362604, dtype: float64
# <ipython-input-26-c7d893d52a43>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['amount_bin_weight'] = data['amount_binned'].map(lambda x: amount_bin_weights.get(x, 1.0))

# %%
#plot
plt.figure(figsize=(10, 6))
sns.barplot(x='amount_binned', y='Fraud_Rate', data=fraud_rate_per_bin)
plt.title('Fraud Rate by Transaction Amount Bin')
plt.xlabel('Transaction Amount Bin')
plt.ylabel('Fraud Rate (%)')
# Out:
# Text(0, 0.5, 'Fraud Rate (%)')

# %% [markdown]
# **4. EDA on Transformed Data**

# %%
#plot the graph
plt.figure(figsize=(10, 6))
sns.violinplot(x='isFraud', y='amount_scaled', data=data, palette='viridis')
plt.title('Distribution of Amount Scaled by isFraud')
plt.xlabel('isFraud')
plt.ylabel('Amount Scaled')
plt.ylim(0,100)
plt.show()
# Out:
# <ipython-input-28-50994a2acd25>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='isFraud', y='amount_scaled', data=data, palette='viridis')

# %% [markdown]
# ***For Non-Fraud(0)***
# Legitimate transactions typically involve smaller monetary values and are clustered within a relatively tight rangem indicating lower variability in their amounts.
#
# ***For Fraud(1):***
# Fraudulant transactions are charaterized by significantly larger monetary values, as evidanced by the higher peak in their distribution. These transactions also exhibit a broader range of values, indicating that fraudsters engage in transactions with greater variability in amounts. The overall shape of the distribution suggests a preference for higher-value transactions, though attempts are made across a wider spectrum of amounts.

# %% [markdown]
# A bar plot, generated using the Seaborn library, was created to visualize the relationship between transaction amount ranges and fraud rates. This plot effectively illustrates the prevalence of fraud across different transaction value brackets, allowing for a clear identification of which amount ranges are most susceptible to fraudulent activity.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#plot
plt.figure(figsize=(10, 6))
sns.barplot(x='amount_binned', y='Fraud_Rate', data=fraud_rate_per_bin, palette='coolwarm')
plt.title('Fraud Rate by Transaction Amount Bin')
plt.xlabel('Transaction Amount Bin')
plt.ylabel('Fraud Rate (%)')
plt.xticks(rotation=-15)
plt.show()
# Out:
# <ipython-input-29-ad289ea72402>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='amount_binned', y='Fraud_Rate', data=fraud_rate_per_bin, palette='coolwarm')

# %%
data.head(30)
# Out:
#     step  type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0      1     1    9839.64  C1231006815      170136.00       160296.36
# 1      1     1    1864.28  C1666544295       21249.00        19384.72
# 2      1     3     181.00  C1305486145         181.00            0.00
# 3      1     0     181.00   C840083671         181.00            0.00
# 4      1     1   11668.14  C2048537720       41554.00        29885.86
# 5      1     1    7817.71    C90045638       53860.00        46042.29
# 6      1     1    7107.77   C154988899      183195.00       176087.23
# 7      1     1    7861.64  C1912850431      176087.23       168225.59
# 8      1     1    4024.36  C1265012928        2671.00            0.00
# 9      1     4    5337.77   C712410124       41720.00        36382.23
# 10     1     4    9644.94  C1900366749        4465.00            0.00
# 11     1     1    3099.97   C249177573       20771.00        17671.03
# ...

# %% [markdown]
# ***Visualizing the Distribution of Log-Transformed Old Balance and New Balance***
#
# A Kernel Density Estimate (KDE) plot was generated to visually compare the distributions of the logarithmically transformed 'oldbalanceOrg' variable, representing the original account balance before the transaction, between fraudulent and non-fraudulent transactions. This plot allows for a direct comparison of the balance distributions, highlighting any potential differences in the way account balances are distributed between fraud and non-fraud cases.

# %%
import warnings
#suppress Future Warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
#kde plot for non-fradulant transactions
sns.kdeplot(data=data[data['isFraud']==0]['amount_scaled'], label='Non-Fraudulent', shade=True)

#kde plot for fradualant transactions
sns.kdeplot(data=data[data['isFraud']==1]['amount_scaled'], label='Fraudulent', shade=True)

#add title and labels
plt.title('Distribution of Amount Scaled by isFraud')
plt.xlabel('Amount Scaled')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
import warnings

# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# KDE plot for non-fraudulent transactions
sns.kdeplot(data=data[data['isFraud'] == 0],
            x='oldbalanceOrg_log', label='Non-Fraud', fill=True, color='blue')

# KDE plot for fraudulent transactions
sns.kdeplot(data=data[data['isFraud'] == 1],
            x='oldbalanceOrg_log', label='Fraud', fill=True, color='red')

# Add labels and title
plt.xlabel("Log of Old Balance")
plt.ylabel("Density")
plt.title("Distribution of Log Old Balance for Fraud & Non-Fraud Transactions")
plt.legend()
plt.show()

# %% [markdown]
# The Kernel Density Estimate (KDE) plot of the logarithmically transformed 'oldbalanceOrg' variable reveals a distinct pattern: fraudulent transactions are more frequently associated with accounts that possess higher initial balances. This observation implies a strategic tendency among fraudsters to target accounts holding significant funds, likely driven by the desire to maximize the potential financial gain from their illicit activities.

# %%
#KDE plot for non-fradulent transactions with fill colors
sns.kdeplot(data=data[data['isFraud']==0]['newbalanceOrig_log'], label='Non-Fraudulent', shade=True)

#KDE plot for fraudulent transactions
sns.kdeplot(data=data[data['isFraud']==1]['newbalanceOrig_log'], label='Fraudulent', shade=True)

#Add title and labels
plt.title('Distribution of New Balance Orig Log by isFraud')
plt.xlabel('New Balance Orig Log')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# **What This Mean**
#
# Analyzing account balances post-transaction reveals a key behavioral distinction: legitimate users typically deplete their funds, resulting in a zero balance, whereas fraudulent actors often leave a remaining, non-zero balance, suggesting an attempt to avoid suspicion or maintain access. This variance provides a powerful signal for fraud detection models, enabling them to identify transactions deviating from the typical "account draining" pattern as potentially fraudulent. By learning this behavior, models can effectively flag transactions that do not conform to the usual user behavior.
#
# **Analyzing Receiver Accounts for Fraud Patterns**
#
# To gain a more comprehensive understanding of fraudulent activities, the analysis will now extend to the receiver accounts, also known as destination accounts. The objective is to identify any distinct patterns or anomalies that differentiate these accounts in fraudulent transactions from those in legitimate ones. Particular attention will be paid to "flip patterns" or unusual behaviors, such as abrupt increases in account balances or other atypical transaction activity, which may serve as indicators of fraudulent fund transfers.

# %%
#KDE plot for non-fraudulent transactions
sns.kdeplot(data=data[data['isFraud']==0], x='oldbalanceDest_log', label='Non-Fraudulent', fill=True, color='green')

# KDE plot for fraudulent transactions
sns.kdeplot(data=data[data['isFraud']==1], x='oldbalanceDest_log', label='Fraudulent', fill=True, color='grey')

# Add labels and title
plt.xlabel("Old Balance Destination Log")
plt.ylabel("Density")
plt.title("Distribution of Old Balance Destination Log for Fraud & Non-Fraud Transactions")
plt.legend()
plt.show()

# %% [markdown]
# * Frudulant transactions tend to empty accounts with new balance near zero.
# * Fraudsters likely operate from accounts with very low initial balances. Non-Fraudulent transactions involve accounts that start and end with higher balances.

# %%
#set figure size
plt.figure(figsize=(10, 6))

#KDE plot for non-fraudulent transactions
sns.kdeplot(data=data[data['isFraud']==0], x='newbalanceDest_log', label='Non-Fraudulent', fill=True, color='green')

# KDE plot for fraudulent transactions
sns.kdeplot(data=data[data['isFraud'] == 1],
            x='newbalanceDest_log', label='Fraud', fill=True, color='purple')

# Add labels and title
plt.xlabel("New Balance Destination Log")
plt.ylabel("Density")
plt.title("Distribution of New Balance Destination Log for Fraud & Non-Fraud Transactions")
plt.legend()
plt.show()

# %% [markdown]
# *  The Kernel Density Estimate (KDE) plot reveals a significant trend: fraudulent transactions frequently involve destination accounts that exhibit exceptionally low initial balances, typically within the 0 to 5 range on the logarithmic scale. This observation points to a potential strategy where fraudsters utilize newly established or previously emptied accounts to receive illicit funds. These funds are likely then rapidly transferred or withdrawn, indicating possible involvement in money laundering operations or the use of mule accounts. The low initial balance of these destination accounts may be a deliberate tactic to minimize suspicion and evade detection.
# *  While the Kernel Density Estimate (KDE) plot highlights a tendency for fraudulent transactions to involve destination accounts with low initial balances (0-15 on the log scale), the significant overlap with non-fraudulent transactions within this range limits its effectiveness as a standalone fraud detection feature. To overcome this limitation and enhance the model's predictive capabilities, a more sophisticated approach is required. This involves integrating the 'oldbalanceDest_log' feature with other relevant variables, such as transaction amount or origin account balance, to create more informative feature combinations. Alternatively, derived features, like balance change ratios, could be engineered to capture more subtle and complex patterns indicative of fraudulent activity. By incorporating these strategies, we can move beyond relying on a single, potentially ambiguous feature and develop a more robust model that effectively identifies fraudulent transactions.

# %% [markdown]
# **5.Advanced Feature Engineering**
#
# **Combining Weights for Enhanced Model Learning**
#
# To sharpen the model's ability to identify the most critical fraudulent transactions, a combined weight column was created, integrating the weights derived from transaction type and transaction amount bins. This consolidated weighting strategy ensures that the model places a higher emphasis on learning from transactions exhibiting both high-risk characteristics: those of 'CASH_OUT' and 'TRANSFER' types, known for their susceptibility to fraud, and those involving substantial amounts, specifically within the 100,000+ and 1,000,000+ ranges. By prioritizing these high-risk combinations, the model's focus is optimized for effective fraud detection.

# %%
# Combine weights
data['combined_weight'] = data['transaction_type_weight'] * data['bin_weight']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bin_weight'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-bc385ad74807> in <cell line: 0>()
#       1 # Combine weights
# ...

# %%
#combine weights
data['combined_weight'] = data['transaction_type_weight'] * data['amount_bin_weight']
# Out:
# <ipython-input-38-351f8b541a2c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['combined_weight'] = data['transaction_type_weight'] * data['amount_bin_weight']

# %% [markdown]
# **Since these columns contain missing values and are affected by outliers, I decided to fill the missing values with the median. The median is a robust measure of central tendency that is less sensitive to outliers, making it a suitable choice for this dataset.**

# %%
from sklearn.impute import SimpleImputer

#initialize SimpleImputer with strategy = 'median'
imputer= SimpleImputer(strategy='median')

# %%
#apply imputer to specific columns
data[['oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest',
      'newbalanceDest']] = imputer.fit_transform(data
       [['oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest',
         'newbalanceDest']])
# Out:
# <ipython-input-40-7e023d5251d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest',

# %% [markdown]
# **To better understand how balances change during transactions, I created two new features:**
# * **balance_diff_Org:** This calculated difference, oldbalanceOrg minus newbalanceOrig, represents the precise amount of funds removed or transferred from the originating account during the transaction. Essentially, it quantifies the debit or outflow from the account.
# * **balance_diff_Dest:** This calculation, newbalanceDest minus oldbalanceDest, reflects the exact amount of funds credited or added to the destination account as a result of the transaction. In essence, it measures the inflow or deposit into the receiving account.
# *  By analyzing these calculated balance differences, we can gain a deeper understanding of how account balances fluctuate for both the sending and receiving parties during transactions. This analysis will help uncover unique patterns of balance changes that may be indicative of fraudulent activities, allowing us to distinguish them from typical, legitimate transactions.

# %% [markdown]
# To mitigate the effects of skewness and outliers present in the 'balance_diff_Org' and 'balance_diff_Dest' features, a logarithmic transformation was applied using the numpy.log1p() function. This specific transformation, which calculates the natural logarithm of (x + 1), is well-suited for non-negative data and effectively compresses the data's range. The resulting features, 'balance_diff_Org_log' and 'balance_diff_Dest_log', now exhibit more normalized distributions, making them more amenable to statistical analysis and improving their utility as input features for predictive modeling.

# %%
data['balance_diff_Org'] = data['oldbalanceOrg'] - data['newbalanceOrig']
data['balance_diff_Dest']= data['oldbalanceDest'] - data['newbalanceDest']
# Out:
# <ipython-input-41-9273e710c946>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['balance_diff_Org'] = data['oldbalanceOrg'] - data['newbalanceOrig']
# <ipython-input-41-9273e710c946>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['balance_diff_Dest']= data['oldbalanceDest'] - data['newbalanceDest']

# %%
data['balance_diff_Org_log'] = np.log1p(data['balance_diff_Org'])  # Log(x+1) for non-negative values
data['balance_diff_Dest_log'] = np.log1p(data['balance_diff_Dest'])
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-42-54fe4b68f98b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['balance_diff_Org_log'] = np.log1p(data['balance_diff_Org'])  # Log(x+1) for non-negative values
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ...

# %% [markdown]
# **Scaling Log-Transfored Features**
#
# Following the logarithmic transformation of 'balance_diff_Org' and 'balance_diff_Dest', the RobustScaler technique was implemented to scale these features. Robust scaling was chosen due to its resilience to outliers, a critical consideration given the potential for extreme values in financial transaction data. Unlike standard scaling methods that rely on mean and standard deviation, RobustScaler utilizes the interquartile range (IQR), providing a more stable and reliable scaling process in the presence of outliers.

# %%
# Replace infinite values with NaN to handle potential errors
data.replace([np.inf, -np.inf], np.nan, inplace=True)

# Define columns to scale (only those that exist)
columns_to_scale = [
    'balance_diff_Org_log',
    'balance_diff_Dest_log',
    'balance_diff_Org'
]

# Ensure all columns exist before scaling
columns_to_scale = [col for col in columns_to_scale if col in data.columns]

# Initialize RobustScaler
scaler = RobustScaler()

# Apply scaling only to existing columns
data[columns_to_scale] = scaler.fit_transform(data[columns_to_scale])

# Display the first few rows of scaled data
print("Scaling complete. First few rows of scaled data:")
print(data.head())
# Out:
# <ipython-input-43-ba41811b5cc1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.replace([np.inf, -np.inf], np.nan, inplace=True)
# Scaling complete. First few rows of scaled data:
#    step  type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1     1   9839.64  C1231006815       170136.0       160296.36
# 1     1     1   1864.28  C1666544295        21249.0        19384.72
# 2     1     3    181.00  C1305486145          181.0            0.00
# 3     1     0    181.00   C840083671          181.0            0.00
# 4     1     1  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  ...  \
# 0  M1979787155             0.0             0.0        0  ...
# 1  M2044282225             0.0             0.0        0  ...
# ...

# %% [markdown]
# **Why To Use Both?**
#
# To prepare the data for modeling, a two-step preprocessing approach was employed. First, a logarithmic transformation was applied to address skewness, effectively bringing extreme values closer together and spreading out smaller values, thereby creating a more symmetrical distribution. Subsequently, RobustScaler was used to scale the log-transformed data. This scaling method, which utilizes the median and interquartile range (IQR), was selected to minimize the impact of outliers. The combined effect of these techniques results in a dataset that is both more normally distributed and less sensitive to extreme values, leading to enhanced model accuracy and stability.

# %% [markdown]
# **6. Final EDA and Visualization**
#
# A scatter plot was generated to investigate the relationship between transaction amounts and the corresponding changes in the origin account's balance, represented by the 'balance_diff_Org' feature. This visual representation aims to reveal any distinctive patterns or anomalies that might differentiate fraudulent transactions from their legitimate counterparts, potentially highlighting key characteristics that contribute to fraud detection.

# %%
data.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'transaction_type_weight', 'amount_scaled',
#        'oldbalanceOrg_log', 'newbalanceOrig_log', 'oldbalanceDest_log',
#        'newbalanceDest_log', 'amount_binned', 'amount_bin_weight',
#        'combined_weight', 'balance_diff_Org', 'balance_diff_Dest',
#        'balance_diff_Org_log', 'balance_diff_Dest_log'],
#       dtype='object')

# %%
#scatter plot of Amount vs Balance Difference
sns.scatterplot(x='amount_scaled', y='balance_diff_Org_log', data=data, hue='isFraud')
plt.title('Scatter Plot of Amount vs Balance Difference')
plt.xlabel('Amount Scaled')
plt.ylabel('Balance Difference Log')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Scatter plot of Amount vs Balance Difference
sns.scatterplot(x='amount', y='balance_diff_Org', hue='isFraud', data=data, alpha=0.5)

# Add titles and labels
plt.title('Amount vs Balance Difference (Origin Account)')
plt.xlabel('Transaction Amount')
plt.ylabel('Balance Difference (Old - New)')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# *   Fraudulent transactions (isFraud = 1) involve the sender sending out large amounts of money, and the sender’s balance is decreasing (positive balance difference), often by a substantial amount.
# *   This indicates that fraudsters are using the sender’s account to send out large sums, depleting the balance, which aligns with typical fraud behavior like theft or unauthorized transfers.

# %%
#Scatter plot amount vs destination balance difference
sns.scatterplot(x='amount', y='balance_diff_Dest', hue='isFraud', data=data, alpha=0.5)

#Add title and label
plt.title('Amount vs Balance Difference (Destination Account)')
plt.xlabel('Transaction Amount')
plt.ylabel('Balance Difference (Old - New)')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'transaction_type_weight', 'amount_scaled',
#        'oldbalanceOrg_log', 'newbalanceOrig_log', 'oldbalanceDest_log',
#        'newbalanceDest_log', 'amount_binned', 'amount_bin_weight',
#        'combined_weight', 'balance_diff_Org', 'balance_diff_Dest',
#        'balance_diff_Org_log', 'balance_diff_Dest_log'],
#       dtype='object')

# %% [markdown]
# * For legitimate transactions (blue, isFraud = 0), when the receiver gets money, their account balance usually increases (negative balance difference, e.g., -0.2 to -1.0), and larger amounts lead to bigger increases in their balance.
# *  For fraudulent transactions (orange, isFraud = 1), even though the receiver receives large amounts of money, their account balance doesn’t increase (balance difference near 0 or positive). This could mean the funds are immediately withdrawn, reversed, or never properly credited, indicating some kind of fraud like money laundering, theft, or account manipulation.

# %% [markdown]
# **7. Model Preparation**
#
# **Preparing Data for Correlation Analysis**
#
# For a more focused and effective correlation analysis, we removed unnecessary columns, streamlining the dataset to include only the transformed variables. This selective reduction simplifies the data, allowing us to concentrate on the most pertinent features for discerning meaningful relationships.

# %%
# Drop irrelevant columns and original variables
columns_to_drop = ['step','amount', 'oldbalanceOrg', 'newbalanceOrig',
                   'newbalanceDest','oldbalanceDest','isFlaggedFraud',
                   'transaction_type_weight','amount_bin_weight','amount_binned',
                   'nameOrig','nameDest']
print(columns_to_drop)
# Out:
# ['step', 'amount', 'oldbalanceOrg', 'newbalanceOrig', 'newbalanceDest', 'oldbalanceDest', 'isFlaggedFraud', 'transaction_type_weight', 'amount_bin_weight', 'amount_binned', 'nameOrig', 'nameDest']

# %%
import pandas as pd

columns_to_drop = ['step', 'amount', 'oldbalanceOrg', 'newbalanceOrig', 'newbalanceDest', 'oldbalanceDest', 'isFlaggedFraud', 'transaction_type_weight', 'bin_weight', 'amount_bin', "nameOrig", "nameDest"]

existing_columns = [col for col in columns_to_drop if col in data.columns]

data = data.drop(columns=existing_columns)

print(data.head())
# Out:
#    type  isFraud  amount_scaled  oldbalanceOrg_log  newbalanceOrig_log  \
# 0     1        0      -0.332937          12.044359           11.984786
# 1     1        0      -0.373767           9.964112            9.872292
# 2     3        1      -0.382384           5.204007            0.000000
# 3     0        1      -0.382384           5.204007            0.000000
# 4     1        0      -0.323576          10.634773           10.305174
#
#    oldbalanceDest_log  newbalanceDest_log amount_binned  amount_bin_weight  \
# 0            0.000000                 0.0        5K-10K                1.0
# 1            0.000000                 0.0         1K-5K                1.0
# 2            0.000000                 0.0       100-500                1.0
# 3            9.960954                 0.0       100-500                1.0
# 4            0.000000                 0.0       10K-50K                1.0
#
#    combined_weight  balance_diff_Org  balance_diff_Dest  balance_diff_Org_log  \
# ...

# %%
data.head(30)
# Out:
#     type  isFraud  amount_scaled  oldbalanceOrg_log  newbalanceOrig_log  \
# 0      1        0      -0.332937          12.044359           11.984786
# 1      1        0      -0.373767           9.964112            9.872292
# 2      3        1      -0.382384           5.204007            0.000000
# 3      0        1      -0.382384           5.204007            0.000000
# 4      1        0      -0.323576          10.634773           10.305174
# 5      1        0      -0.343288          10.894162           10.737337
# 6      1        0      -0.346923          12.118312           12.078740
# 7      1        0      -0.343063          12.078740           12.033067
# 8      1        0      -0.362708           7.890583            0.000000
# 9      4        0      -0.355984          10.638760           10.501863
# 10     4        0      -0.333934           8.404248            0.000000
# 11     1        0      -0.367440           9.941361            9.779738
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#correlation matrix with datatypes and numner
correlation_matrix = data.select_dtypes(include=['number']).corr()

#plot
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# **Dropping Highly Correlated Variables**
#
# Following the generation of a heatmap to visualize correlations within the dataset, several variables were found to exhibit strong interdependencies. To mitigate the issue of multicollinearity, which can negatively impact model performance, and to streamline the dataset for subsequent analysis, specific columns were removed.
#
# balance_diff_Dest balance_diff_Dest_log balance_diff_Org_log newbalanceDest_log Multicollinearity can negatively impact model performance by making it difficult to interpret the importance of individual features and by introducing redundancy.

# %%
columns_to_drop = [ 'balance_diff_Dest','balance_diff_Dest_log','balance_diff_Org_log','newbalanceDest_log']


# Drop the specified columns
data = data.drop(columns=columns_to_drop)

# Check the updated DataFrame
print(data.head())
# Out:
#    type  isFraud  amount_scaled  oldbalanceOrg_log  newbalanceOrig_log  \
# 0     1        0      -0.332937          12.044359           11.984786
# 1     1        0      -0.373767           9.964112            9.872292
# 2     3        1      -0.382384           5.204007            0.000000
# 3     0        1      -0.382384           5.204007            0.000000
# 4     1        0      -0.323576          10.634773           10.305174
#
#    oldbalanceDest_log amount_binned  amount_bin_weight  combined_weight  \
# 0            0.000000        5K-10K                1.0              1.0
# 1            0.000000         1K-5K                1.0              1.0
# 2            0.000000       100-500                1.0              2.0
# 3            9.960954       100-500                1.0              2.0
# 4            0.000000       10K-50K                1.0              1.0
#
#    balance_diff_Org
# 0          0.969372
# 1          0.183663
# 2          0.017832
# ...

# %%
data.columns
# Out:
# Index(['type', 'isFraud', 'amount_scaled', 'oldbalanceOrg_log',
#        'newbalanceOrig_log', 'oldbalanceDest_log', 'amount_binned',
#        'amount_bin_weight', 'combined_weight', 'balance_diff_Org'],
#       dtype='object')

# %% [markdown]
# **Checking Multicollinearity Using Variance Inflation Factor (VIF)**
#
#
# To verify the absence of harmful multicollinearity among the remaining numerical columns, we computed the Variance Inflation Factor (VIF) for each feature. The VIF measures the degree to which the variance of a regression coefficient is increased due to collinearity with other predictor variables. A VIF value exceeding 5 or 10 is commonly interpreted as a sign of significant multicollinearity, suggesting that the affected variables are strongly correlated and potentially redundant.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Grab the numerical columns we want to check for multicollinearity
X = data[['amount_scaled', 'oldbalanceOrg_log', 'newbalanceOrig_log', 'oldbalanceDest_log', 'balance_diff_Org']]

# %%
# Handle missing values (replace NaNs and Infs)
X = X.replace([np.inf, -np.inf], np.nan)
X = X.fillna(X.mean())

# Setup a DataFrame to store the VIF results
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

# Calculate VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

# Show the VIF results
print(vif_data)
# Out:
#               feature       VIF
# 0       amount_scaled  1.090552
# 1   oldbalanceOrg_log  5.028138
# 2  newbalanceOrig_log  4.708820
# 3  oldbalanceDest_log  1.691036
# 4    balance_diff_Org  1.266884

# %% [markdown]
# **Dropping a Feature with High Multicollinearity**
#
# The Variance Inflation Factor (VIF) calculation revealed that the 'oldbalanceOrg_log' column exhibited a VIF of 5.028135, signaling a potential issue with moderate to high multicollinearity. To enhance the model's stability and prevent adverse effects from this collinearity, the 'oldbalanceOrg_log' column was removed from the dataset.

# %%
#list the columns we want to drop because it is too correlated with others
columns_to_drop=['oldbalanceOrg_log']

#drop the column from the dataset
data= data.drop(columns=columns_to_drop)

#take a quick look at the updated daataset to make sure the column is gone
print(data.head())
# Out:
#    type  isFraud  amount_scaled  newbalanceOrig_log  oldbalanceDest_log  \
# 0     1        0      -0.332937           11.984786            0.000000
# 1     1        0      -0.373767            9.872292            0.000000
# 2     3        1      -0.382384            0.000000            0.000000
# 3     0        1      -0.382384            0.000000            9.960954
# 4     1        0      -0.323576           10.305174            0.000000
#
#   amount_binned  amount_bin_weight  combined_weight  balance_diff_Org
# 0        5K-10K                1.0              1.0          0.969372
# 1         1K-5K                1.0              1.0          0.183663
# 2       100-500                1.0              2.0          0.017832
# 3       100-500                1.0              2.0          0.017832
# 4       10K-50K                1.0              1.0          1.149510

# %%
print(data.columns)
# Out:
# Index(['type', 'isFraud', 'amount_scaled', 'newbalanceOrig_log',
#        'oldbalanceDest_log', 'amount_binned', 'amount_bin_weight',
#        'combined_weight', 'balance_diff_Org'],
#       dtype='object')

# %%
data
# Out:
#          type  isFraud  amount_scaled  newbalanceOrig_log  oldbalanceDest_log  \
# 0           1        0      -0.332937           11.984786            0.000000
# 1           1        0      -0.373767            9.872292            0.000000
# 2           3        1      -0.382384            0.000000            0.000000
# 3           0        1      -0.382384            0.000000            9.960954
# 4           1        0      -0.323576           10.305174            0.000000
# ...       ...      ...            ...                 ...                 ...
# 6362615     0        1       1.355688            0.000000            0.000000
# 6362616     3        1      31.927868            0.000000            0.000000
# 6362617     0        1      31.927868            0.000000           11.134441
# 6362618     3        1       3.968266            0.000000            0.000000
# 6362619     0        1       3.968266            0.000000           15.688865
#
# ...

# %% [markdown]
# **8. Model Building and Evaluation**

# %%
#Import necessary libraries
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier  # Using SGDClassifier for faster training
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
import numpy as np
import pandas as pd

# %%
X = data.drop(columns=['isFraud'])  # Features (excluding the target)
y = data['isFraud']  # Target variable

# 1. Check for NaNs in y
print("NaNs in y before handling:", y.isna().sum())

# 2. Handle NaNs in y (remove rows with NaN in y)
# You can also impute if you prefer, but removing is usually safer for target variables
nan_indices = y.isna()
X = X[~nan_indices]
y = y[~nan_indices]

# 3. Check for NaNs in y after handling
print("NaNs in y after handling:", y.isna().sum())
# Out:
# NaNs in y before handling: 0
# NaNs in y after handling: 0

# %%
# Downsample the majority class to reduce dataset size (optional, adjust sampling_strategy)
rus = RandomUnderSampler(sampling_strategy=0.1, random_state=42)  # Keep 10% of the majority class
X_under, y_under = rus.fit_resample(X, y)

# %%
# Import necessary libraries
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier  # Using SGDClassifier for faster training
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
import numpy as np
import pandas as pd

# Separate features (X) and target (y), but keep 'combined_weight' for now
X = data.drop(columns=['isFraud'])  # Features (excluding the target)
y = data['isFraud']  # Target variable

# 1. Check for NaNs in y
print("NaNs in y before handling:", y.isna().sum())

# 2. Handle NaNs in y (remove rows with NaN in y)
nan_indices = y.isna()
X = X[~nan_indices]
y = y[~nan_indices]

# Downsample the majority class to reduce dataset size (optional, adjust sampling_strategy)
rus = RandomUnderSampler(sampling_strategy=0.1, random_state=42)  # Keep 10% of the majority class
X_under, y_under = rus.fit_resample(X, y)

# Handle string values in X_under before SMOTE
def convert_range_to_average(value):
    if isinstance(value, str) and '-' in value:
        try:
            lower, upper = map(float, value.split('-'))
            return (lower + upper) / 2
        except ValueError:
            return np.nan  # Handle bad data.
    else:
        try:
            return float(value)  # Convert to float if not a string range.
        except ValueError:
            return np.nan  # Handle bad data.

for col in X_under.columns:
    if X_under[col].dtype == 'object':
        X_under[col] = X_under[col].apply(convert_range_to_average)

# Handle categorical and NaN values.
for col in X_under.columns:
    if X_under[col].dtype == 'category':
        # Handle categorical columns (example: one-hot encoding)
        X_under = pd.get_dummies(X_under, columns=[col], dummy_na=True) #add dummy_na=True to handle nan values.
    else:
        # Handle NaN values for numerical columns
        X_under[col] = X_under[col].fillna(X_under[col].mean())

# Apply SMOTE to balance classes (optimized with k_neighbors=1 for speed)
smote = SMOTE(sampling_strategy=0.5, k_neighbors=1, random_state=42)  # Balance classes
X_resampled, y_resampled = smote.fit_resample(X_under, y_under)

# Separate 'combined_weight' from the features
combined_weight_resampled = X_resampled['combined_weight']  # Extract sample weights
X_resampled = X_resampled.drop(columns=['combined_weight'])  # Drop weights from features

# Convert to NumPy arrays for faster processing
X_resampled, y_resampled = X_resampled.values, y_resampled.values

# Single stratified train-test split
X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X_resampled, y_resampled, combined_weight_resampled,
    test_size=0.2,  # 20% for testing
    stratify=y_resampled,  # Preserve class balance
    random_state=42  # For reproducibility
)

# Define a faster model (SGDClassifier with log loss for logistic regression)
model = SGDClassifier(
    loss='log_loss',  # Equivalent to logistic regression
    penalty='l1',  # L1 regularization for feature selection
    alpha=0.0001,  # Regularization strength
    max_iter=1000,  # Maximum iterations
    tol=1e-3,  # Tolerance for stopping
    random_state=42,  # For reproducibility
    n_jobs=-1  # Use all CPU cores for faster training
)

# Train the model with sample weights
model.fit(X_train, y_train, sample_weight=weights_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)  # Calculate accuracy
report = classification_report(y_test, y_pred)  # Generate classification report
conf_matrix = confusion_matrix(y_test, y_pred)  # Generate confusion matrix

# Print results
print(f" Accuracy: {accuracy:.4f}")
print("\n Classification Report:\n", report)
print("\n Confusion Matrix:\n", conf_matrix)
# Out:
# NaNs in y before handling: 0
#  Accuracy: 0.9561
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     16394
#            1       0.94      0.93      0.93      8197
#
#     accuracy                           0.96     24591
#    macro avg       0.95      0.95      0.95     24591
# weighted avg       0.96      0.96      0.96     24591
#
#
#  Confusion Matrix:
#  [[15927   467]
#  [  613  7584]]

# %%
# Training set predictions
y_train_pred = model.predict(X_train)
train_accuracy = accuracy_score(y_train, y_train_pred)
train_report = classification_report(y_train, y_train_pred)
print(f"Training Accuracy: {train_accuracy:.4f}")
print("Training Report:\n", train_report)
# Out:
# Training Accuracy: 0.9562
# Training Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     65576
#            1       0.94      0.92      0.93     32788
#
#     accuracy                           0.96     98364
#    macro avg       0.95      0.95      0.95     98364
# weighted avg       0.96      0.96      0.96     98364

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from scipy.stats import ttest_ind

# %%
# Model Training
print("Training Random Forest Model...")
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# Training Random Forest Model...
# RandomForestClassifier(random_state=42)

# %%
# Predictions
y_pred = model.predict(X_test)

# %%
# Model Evaluation
print("Evaluating model...")
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
# Out:
# Evaluating model...

# %%
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9978
# Precision: 0.9949
# Recall: 0.9985
# F1-score: 0.9967
# Confusion Matrix:
#  [[16352    42]
#  [   12  8185]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     16394
#            1       0.99      1.00      1.00      8197
#
#     accuracy                           1.00     24591
#    macro avg       1.00      1.00      1.00     24591
# weighted avg       1.00      1.00      1.00     24591

# %% [markdown]
# Performing the A/B testingon this model

# %%
# A/B Testing - Performance Comparison Between Two Models
print("Performing A/B Testing...")
model_b = RandomForestClassifier(n_estimators=50, random_state=42)  # Alternative model
model_b.fit(X_train, y_train)
y_pred_b = model_b.predict(X_test)

accuracy_b = accuracy_score(y_test, y_pred_b)
f1_b = f1_score(y_test, y_pred_b)
# Out:
# Performing A/B Testing...

# %%
# T-test for statistical significance
t_stat, p_value = ttest_ind(y_pred, y_pred_b)
print(f"Model A Accuracy: {accuracy:.4f}, F1-score: {f1:.4f}")
print(f"Model B Accuracy: {accuracy_b:.4f}, F1-score: {f1_b:.4f}")
print(f"T-test statistic: {t_stat:.4f}, P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Statistically significant difference found.")
else:
    print("No significant difference between models.")
# Out:
# Model A Accuracy: 0.9978, F1-score: 0.9967
# Model B Accuracy: 0.9980, F1-score: 0.9970
# T-test statistic: 0.0382, P-value: 0.9695
# No significant difference between models.

# %% [markdown]
# **Visualize Results**

# %%
from sklearn.metrics import confusion_matrix

y_pred_all = model.predict(X_resampled)

cm = confusion_matrix(y_resampled, y_pred_all)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ***ROC Curve***

# %%
from sklearn.metrics import roc_curve, auc

y_pred_proba = model.predict_proba(X_resampled)[:, 1]

fpr, tpr, thresholds = roc_curve(y_resampled, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **Final Note that is on Model Selection and Feature Engineering**
#
# While working on this project, I did experiment with 8-9 different features in engineering techniques and tried multiple models, that includes *XGBoost and Random Forest*.
#
# Moreover, these models tended to overfit because they they learned too deeply from the training data, capturing noise rather than general patterns. This dataset is highly sensitive, and even small changes in features can drastically affect the model's performance. As a result, I spent a significant amount of time refining the features and selecting the right model to avoid overfitting. In some cases, I had to discard certain insights or features because they made the data too complex or unstable for the model to generalize well. Ultimately, I settled on Logistic Regression for its simplicity and robustness, which provided a good balance between performance and interpretability.
